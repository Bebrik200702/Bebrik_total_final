# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

SCALING_WEIGHTS = [100/15, 100/8, 100/100]

# %%
# !gdown 1IAZw8lzHB7BiENiJxBRYkvgXEPmeS0Gu
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1IAZw8lzHB7BiENiJxBRYkvgXEPmeS0Gu
# To: /content/ml_data_onsite_start.pickle
# 100% 15.7M/15.7M [00:00<00:00, 35.0MB/s]

# %%
data = pd.read_pickle('ml_data_onsite_start.pickle')

X_train = data['X']['train']
y_train = data['y']['train']

X_val = data['X']['val']
y_val = data['y']['val']

X_test = data['X']['live_test']

# %%
def vis(arr):
  plt.figure(figsize=(8, 8))

  cnt = 1
  for z in range(5):
    for q in range(6):
      plt.subplot(5, 6, cnt)
      plt.imshow(arr[:, :, z, q], vmin=-40, vmax=40, cmap='hsv')
      plt.grid()
      plt.axis('off')
      cnt += 1
  plt.tight_layout()
vis(X_train[0])

# %%
def test_solution(X_train, y_train, X_val, y_val, feature_num=0):
    assert X_train.shape[-1] <= 300, "Too many features! Should be less than 300"
    assert X_val.shape[-1] <= 300, "Too many features! Should be less than 300"

    model =  LinearRegression().fit(
        X_train,
        y_train[:, feature_num]
    )
    predictions = model.predict(X_val)
    rmse = mean_squared_error(
        predictions,
        y_val[:, feature_num]
    )**.5
    normalized_rmse = rmse * SCALING_WEIGHTS[feature_num]
    print(f"Property #{feature_num}:    raw RMSE={rmse:.6f}")
    print(f"Property #{feature_num}: scaled RMSE={normalized_rmse:.6f}")
    return round(normalized_rmse, 6)

# %%
def generate_predictions(X_train, y_train, X_test, feature_num=0):
    assert X_train.shape[-1] <= 300
    assert X_test.shape[-1] <= 300

    model =  LinearRegression().fit(
        X_train,
        y_train[:, feature_num]
    )
    predictions = model.predict(X_test)
    return predictions

# %%
# load the test dataset
# !gdown 1K_KNlfIuusgQjeN3gWJ2htutbO2iX7YE
loaded = pd.read_pickle("ml_data_onsite_final_test.pickle")
X_test_final = loaded['X']['final_test']
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1K_KNlfIuusgQjeN3gWJ2htutbO2iX7YE
# To: /content/ml_data_onsite_final_test.pickle
# 100% 14.3M/14.3M [00:00<00:00, 68.4MB/s]

# %%
def construct_features(Xs):
  from itertools import combinations

  all_features = []
  for x in Xs:
    cur_features = []
    for q in range(6):
      features_q = [
          x[:,:,:, q].mean(),
          x[:,:,:, q].max(),
          x[:,:,:, q].min(),
          x[:,:,:, q].std(),
          x[:,:,:, q].max() - x[:,:,:, q].min()
      ]
      cur_features.append(features_q)
    all_features.append(np.stack(cur_features).ravel())

  features = np.stack(all_features)

  comb_features = []

  for comb in combinations(range(30),r=2):
    cur_features = np.concatenate([
        (features[:, comb[0]] - features[:, comb[1]]).reshape(-1,1),
        (features[:, comb[0]] + features[:, comb[1]]).reshape(-1,1),
        (features[:, comb[0]] * features[:, comb[1]]).reshape(-1,1),
        (features[:, comb[0]] / features[:, comb[1]]).reshape(-1,1)
    ],axis=1)
    comb_features.append(cur_features)

  comb_features = np.concatenate(comb_features,axis=1)

  all_features = np.concatenate([all_features, comb_features],axis=1)

  all_features[np.isnan(all_features)] = 0

  all_features[all_features == np.inf] = 1000
  all_features[all_features == -np.inf] = -1000

  return all_features

# %%
X_train_c = construct_features(X_train)
X_val_c = construct_features(X_val)
# Out:
# <ipython-input-7-8ff1a3e9b313>:27: RuntimeWarning: divide by zero encountered in divide
#   (features[:, comb[0]] / features[:, comb[1]]).reshape(-1,1)

# %%
features_results = []


for feature_num in range(3):
  features_results_cur = {}
  for i in range(200):
    idxs = np.random.choice(range(1770), size=(100, ), replace=False)
    X_train_cur = X_train_c[:, idxs]
    X_val_cur = X_val_c[:, idxs]

    score = test_solution(
        X_train_cur,
        y_train,
        X_val_cur,
        y_val,
        feature_num=feature_num
    )
    print('='*16)
    print(f"feature num {feature_num}, score = {score:.6f}")
    features_results_cur[score] = idxs
  features_results.append(features_results_cur)
# Out:
# Property #0:    raw RMSE=0.334912
# Property #0: scaled RMSE=2.232748
# ================
# feature num 0, score = 2.232748
# Property #0:    raw RMSE=0.250723
# Property #0: scaled RMSE=1.671488
# ================
# feature num 0, score = 1.671488
# Property #0:    raw RMSE=0.271950
# Property #0: scaled RMSE=1.812998
# ================
# feature num 0, score = 1.812998
# Property #0:    raw RMSE=0.259486
# Property #0: scaled RMSE=1.729908
# ================
# feature num 0, score = 1.729908
# Property #0:    raw RMSE=0.257143
# Property #0: scaled RMSE=1.714285
# ================
# feature num 0, score = 1.714285
# Property #0:    raw RMSE=0.320449
# Property #0: scaled RMSE=2.136324
# ================
# feature num 0, score = 2.136324
# Property #0:    raw RMSE=0.319993
# Property #0: scaled RMSE=2.133288
# ================
# feature num 0, score = 2.133288
# Property #0:    raw RMSE=0.369567
# Property #0: scaled RMSE=2.463781
# ================
# feature num 0, score = 2.463781
# Property #0:    raw RMSE=0.364235
# Property #0: scaled RMSE=2.428231
# ================
# feature num 0, score = 2.428231
# Property #0:    raw RMSE=0.275980
# Property #0: scaled RMSE=1.839865
# ================
# feature num 0, score = 1.839865
# Property #0:    raw RMSE=0.290379
# Property #0: scaled RMSE=1.935859
# ================
# feature num 0, score = 1.935859
# Property #0:    raw RMSE=0.232690
# Property #0: scaled RMSE=1.551266
# ================
# feature num 0, score = 1.551266
# Property #0:    raw RMSE=0.256886
# Property #0: scaled RMSE=1.712574
# ================
# feature num 0, score = 1.712574
# Property #0:    raw RMSE=0.272246
# Property #0: scaled RMSE=1.814970
# ================
# feature num 0, score = 1.814970
# Property #0:    raw RMSE=0.275112
# Property #0: scaled RMSE=1.834082
# ================
# feature num 0, score = 1.834082
# Property #0:    raw RMSE=0.228021
# Property #0: scaled RMSE=1.520137
# ================
# feature num 0, score = 1.520137
# Property #0:    raw RMSE=0.235292
# Property #0: scaled RMSE=1.568616
# ================
# feature num 0, score = 1.568616
# Property #0:    raw RMSE=0.319125
# Property #0: scaled RMSE=2.127501
# ================
# feature num 0, score = 2.127501
# Property #0:    raw RMSE=0.279393
# Property #0: scaled RMSE=1.862620
# ================
# feature num 0, score = 1.862620
# Property #0:    raw RMSE=0.263609
# Property #0: scaled RMSE=1.757390
# ================
# feature num 0, score = 1.757390
# Property #0:    raw RMSE=0.252617
# Property #0: scaled RMSE=1.684114
# ================
# feature num 0, score = 1.684114
# Property #0:    raw RMSE=0.301949
# Property #0: scaled RMSE=2.012990
# ================
# feature num 0, score = 2.012990
# Property #0:    raw RMSE=0.300343
# Property #0: scaled RMSE=2.002289
# ================
# feature num 0, score = 2.002289
# Property #0:    raw RMSE=0.275765
# Property #0: scaled RMSE=1.838434
# ================
# feature num 0, score = 1.838434
# Property #0:    raw RMSE=0.259803
# Property #0: scaled RMSE=1.732017
# ================
# feature num 0, score = 1.732017
# Property #0:    raw RMSE=0.410012
# Property #0: scaled RMSE=2.733414
# ================
# feature num 0, score = 2.733414
# Property #0:    raw RMSE=0.211004
# Property #0: scaled RMSE=1.406694
# ================
# feature num 0, score = 1.406694
# Property #0:    raw RMSE=0.281433
# Property #0: scaled RMSE=1.876221
# ================
# feature num 0, score = 1.876221
# Property #0:    raw RMSE=0.341787
# Property #0: scaled RMSE=2.278583
# ================
# feature num 0, score = 2.278583
# Property #0:    raw RMSE=0.264414
# Property #0: scaled RMSE=1.762762
# ================
# feature num 0, score = 1.762762
# Property #0:    raw RMSE=0.271761
# Property #0: scaled RMSE=1.811741
# ================
# feature num 0, score = 1.811741
# Property #0:    raw RMSE=0.333701
# Property #0: scaled RMSE=2.224671
# ================
# feature num 0, score = 2.224671
# Property #0:    raw RMSE=0.376237
# Property #0: scaled RMSE=2.508244
# ================
# feature num 0, score = 2.508244
# Property #0:    raw RMSE=0.290789
# Property #0: scaled RMSE=1.938596
# ================
# feature num 0, score = 1.938596
# Property #0:    raw RMSE=0.265623
# Property #0: scaled RMSE=1.770819
# ================
# feature num 0, score = 1.770819
# Property #0:    raw RMSE=0.323120
# Property #0: scaled RMSE=2.154133
# ================
# feature num 0, score = 2.154133
# Property #0:    raw RMSE=0.294022
# Property #0: scaled RMSE=1.960148
# ================
# feature num 0, score = 1.960148
# Property #0:    raw RMSE=0.205094
# Property #0: scaled RMSE=1.367290
# ================
# feature num 0, score = 1.367290
# Property #0:    raw RMSE=0.245584
# Property #0: scaled RMSE=1.637227
# ================
# feature num 0, score = 1.637227
# Property #0:    raw RMSE=0.286527
# Property #0: scaled RMSE=1.910182
# ================
# feature num 0, score = 1.910182
# Property #0:    raw RMSE=0.278465
# Property #0: scaled RMSE=1.856433
# ================
# feature num 0, score = 1.856433
# Property #0:    raw RMSE=0.297036
# Property #0: scaled RMSE=1.980237
# ================
# feature num 0, score = 1.980237
# Property #0:    raw RMSE=0.240993
# Property #0: scaled RMSE=1.606622
# ================
# feature num 0, score = 1.606622
# Property #0:    raw RMSE=0.259538
# Property #0: scaled RMSE=1.730256
# ================
# feature num 0, score = 1.730256
# Property #0:    raw RMSE=0.256157
# Property #0: scaled RMSE=1.707713
# ================
# feature num 0, score = 1.707713
# Property #0:    raw RMSE=0.238576
# Property #0: scaled RMSE=1.590507
# ================
# feature num 0, score = 1.590507
# Property #0:    raw RMSE=0.300920
# Property #0: scaled RMSE=2.006137
# ================
# feature num 0, score = 2.006137
# Property #0:    raw RMSE=0.312721
# Property #0: scaled RMSE=2.084807
# ================
# feature num 0, score = 2.084807
# Property #0:    raw RMSE=0.337778
# Property #0: scaled RMSE=2.251852
# ================
# feature num 0, score = 2.251852
# Property #0:    raw RMSE=0.288739
# Property #0: scaled RMSE=1.924929
# ================
# feature num 0, score = 1.924929
# Property #0:    raw RMSE=0.288446
# Property #0: scaled RMSE=1.922974
# ================
# feature num 0, score = 1.922974
# Property #0:    raw RMSE=0.240877
# Property #0: scaled RMSE=1.605847
# ================
# feature num 0, score = 1.605847
# Property #0:    raw RMSE=0.261440
# Property #0: scaled RMSE=1.742934
# ================
# feature num 0, score = 1.742934
# Property #0:    raw RMSE=0.316461
# Property #0: scaled RMSE=2.109738
# ================
# feature num 0, score = 2.109738
# Property #0:    raw RMSE=0.295609
# Property #0: scaled RMSE=1.970728
# ================
# feature num 0, score = 1.970728
# Property #0:    raw RMSE=0.373638
# Property #0: scaled RMSE=2.490922
# ================
# feature num 0, score = 2.490922
# Property #0:    raw RMSE=0.262441
# Property #0: scaled RMSE=1.749609
# ================
# feature num 0, score = 1.749609
# Property #0:    raw RMSE=0.284734
# Property #0: scaled RMSE=1.898229
# ================
# feature num 0, score = 1.898229
# Property #0:    raw RMSE=0.255229
# Property #0: scaled RMSE=1.701528
# ================
# feature num 0, score = 1.701528
# Property #0:    raw RMSE=0.302374
# Property #0: scaled RMSE=2.015825
# ================
# feature num 0, score = 2.015825
# Property #0:    raw RMSE=0.246853
# Property #0: scaled RMSE=1.645689
# ================
# feature num 0, score = 1.645689
# Property #0:    raw RMSE=0.291570
# Property #0: scaled RMSE=1.943799
# ================
# feature num 0, score = 1.943799
# Property #0:    raw RMSE=0.325222
# Property #0: scaled RMSE=2.168145
# ================
# feature num 0, score = 2.168145
# Property #0:    raw RMSE=0.303423
# Property #0: scaled RMSE=2.022820
# ================
# feature num 0, score = 2.022820
# Property #0:    raw RMSE=0.281275
# Property #0: scaled RMSE=1.875169
# ================
# feature num 0, score = 1.875169
# Property #0:    raw RMSE=0.269847
# Property #0: scaled RMSE=1.798978
# ================
# feature num 0, score = 1.798978
# Property #0:    raw RMSE=0.261185
# Property #0: scaled RMSE=1.741232
# ================
# feature num 0, score = 1.741232
# Property #0:    raw RMSE=0.257931
# Property #0: scaled RMSE=1.719540
# ================
# feature num 0, score = 1.719540
# Property #0:    raw RMSE=0.332733
# Property #0: scaled RMSE=2.218218
# ================
# feature num 0, score = 2.218218
# Property #0:    raw RMSE=0.403717
# Property #0: scaled RMSE=2.691446
# ================
# feature num 0, score = 2.691446
# Property #0:    raw RMSE=0.296569
# Property #0: scaled RMSE=1.977123
# ================
# feature num 0, score = 1.977123
# Property #0:    raw RMSE=0.310607
# Property #0: scaled RMSE=2.070711
# ================
# feature num 0, score = 2.070711
# Property #0:    raw RMSE=0.397779
# Property #0: scaled RMSE=2.651860
# ================
# feature num 0, score = 2.651860
# Property #0:    raw RMSE=0.281323
# Property #0: scaled RMSE=1.875486
# ================
# feature num 0, score = 1.875486
# Property #0:    raw RMSE=0.288881
# Property #0: scaled RMSE=1.925870
# ================
# feature num 0, score = 1.925870
# Property #0:    raw RMSE=0.223753
# Property #0: scaled RMSE=1.491689
# ================
# feature num 0, score = 1.491689
# Property #0:    raw RMSE=0.271637
# Property #0: scaled RMSE=1.810917
# ================
# feature num 0, score = 1.810917
# Property #0:    raw RMSE=0.264114
# Property #0: scaled RMSE=1.760763
# ================
# feature num 0, score = 1.760763
# Property #0:    raw RMSE=0.306071
# Property #0: scaled RMSE=2.040473
# ================
# feature num 0, score = 2.040473
# Property #0:    raw RMSE=0.274881
# Property #0: scaled RMSE=1.832540
# ================
# feature num 0, score = 1.832540
# Property #0:    raw RMSE=0.253411
# Property #0: scaled RMSE=1.689406
# ================
# feature num 0, score = 1.689406
# Property #0:    raw RMSE=0.277784
# Property #0: scaled RMSE=1.851891
# ================
# feature num 0, score = 1.851891
# Property #0:    raw RMSE=0.297639
# Property #0: scaled RMSE=1.984263
# ================
# feature num 0, score = 1.984263
# Property #0:    raw RMSE=0.336906
# Property #0: scaled RMSE=2.246039
# ================
# feature num 0, score = 2.246039
# Property #0:    raw RMSE=0.239953
# Property #0: scaled RMSE=1.599686
# ================
# feature num 0, score = 1.599686
# Property #0:    raw RMSE=0.234353
# Property #0: scaled RMSE=1.562350
# ================
# feature num 0, score = 1.562350
# Property #0:    raw RMSE=0.339699
# Property #0: scaled RMSE=2.264659
# ================
# feature num 0, score = 2.264659
# Property #0:    raw RMSE=0.313779
# Property #0: scaled RMSE=2.091860
# ================
# feature num 0, score = 2.091860
# Property #0:    raw RMSE=0.266470
# Property #0: scaled RMSE=1.776466
# ================
# feature num 0, score = 1.776466
# Property #0:    raw RMSE=0.241449
# Property #0: scaled RMSE=1.609657
# ================
# feature num 0, score = 1.609657
# Property #0:    raw RMSE=0.264959
# Property #0: scaled RMSE=1.766396
# ================
# feature num 0, score = 1.766396
# Property #0:    raw RMSE=0.299539
# Property #0: scaled RMSE=1.996928
# ================
# feature num 0, score = 1.996928
# Property #0:    raw RMSE=0.258273
# Property #0: scaled RMSE=1.721823
# ================
# feature num 0, score = 1.721823
# Property #0:    raw RMSE=0.233707
# Property #0: scaled RMSE=1.558049
# ================
# feature num 0, score = 1.558049
# Property #0:    raw RMSE=0.236236
# Property #0: scaled RMSE=1.574908
# ================
# feature num 0, score = 1.574908
# Property #0:    raw RMSE=0.252539
# Property #0: scaled RMSE=1.683594
# ================
# feature num 0, score = 1.683594
# Property #0:    raw RMSE=0.279558
# Property #0: scaled RMSE=1.863718
# ================
# feature num 0, score = 1.863718
# Property #0:    raw RMSE=0.271125
# Property #0: scaled RMSE=1.807497
# ================
# feature num 0, score = 1.807497
# Property #0:    raw RMSE=0.273504
# Property #0: scaled RMSE=1.823358
# ================
# feature num 0, score = 1.823358
# Property #0:    raw RMSE=0.303281
# Property #0: scaled RMSE=2.021874
# ================
# feature num 0, score = 2.021874
# Property #0:    raw RMSE=0.290462
# Property #0: scaled RMSE=1.936411
# ================
# feature num 0, score = 1.936411
# Property #0:    raw RMSE=0.352183
# Property #0: scaled RMSE=2.347889
# ================
# feature num 0, score = 2.347889
# Property #0:    raw RMSE=0.275235
# Property #0: scaled RMSE=1.834898
# ================
# feature num 0, score = 1.834898
# Property #0:    raw RMSE=0.272765
# Property #0: scaled RMSE=1.818433
# ================
# feature num 0, score = 1.818433
# Property #0:    raw RMSE=0.242753
# Property #0: scaled RMSE=1.618354
# ================
# feature num 0, score = 1.618354
# Property #0:    raw RMSE=0.269836
# Property #0: scaled RMSE=1.798909
# ================
# feature num 0, score = 1.798909
# Property #0:    raw RMSE=0.307333
# Property #0: scaled RMSE=2.048886
# ================
# feature num 0, score = 2.048886
# Property #0:    raw RMSE=0.288315
# Property #0: scaled RMSE=1.922100
# ================
# feature num 0, score = 1.922100
# Property #0:    raw RMSE=0.292811
# Property #0: scaled RMSE=1.952074
# ================
# feature num 0, score = 1.952074
# Property #0:    raw RMSE=0.299553
# Property #0: scaled RMSE=1.997022
# ================
# feature num 0, score = 1.997022
# Property #0:    raw RMSE=0.335087
# Property #0: scaled RMSE=2.233915
# ================
# feature num 0, score = 2.233915
# Property #0:    raw RMSE=0.260792
# Property #0: scaled RMSE=1.738615
# ================
# feature num 0, score = 1.738615
# Property #0:    raw RMSE=0.253791
# Property #0: scaled RMSE=1.691938
# ================
# feature num 0, score = 1.691938
# Property #0:    raw RMSE=0.254929
# Property #0: scaled RMSE=1.699525
# ================
# feature num 0, score = 1.699525
# Property #0:    raw RMSE=0.261714
# Property #0: scaled RMSE=1.744759
# ================
# feature num 0, score = 1.744759
# Property #0:    raw RMSE=0.211680
# Property #0: scaled RMSE=1.411199
# ================
# feature num 0, score = 1.411199
# Property #0:    raw RMSE=0.277024
# Property #0: scaled RMSE=1.846826
# ================
# feature num 0, score = 1.846826
# Property #0:    raw RMSE=0.277046
# Property #0: scaled RMSE=1.846970
# ================
# feature num 0, score = 1.846970
# Property #0:    raw RMSE=0.273084
# Property #0: scaled RMSE=1.820562
# ================
# feature num 0, score = 1.820562
# Property #0:    raw RMSE=0.340649
# Property #0: scaled RMSE=2.270991
# ================
# feature num 0, score = 2.270991
# Property #0:    raw RMSE=0.297079
# Property #0: scaled RMSE=1.980526
# ================
# feature num 0, score = 1.980526
# Property #0:    raw RMSE=0.288839
# Property #0: scaled RMSE=1.925594
# ================
# feature num 0, score = 1.925594
# Property #0:    raw RMSE=0.282184
# Property #0: scaled RMSE=1.881229
# ================
# feature num 0, score = 1.881229
# Property #0:    raw RMSE=0.402631
# Property #0: scaled RMSE=2.684204
# ================
# feature num 0, score = 2.684204
# Property #0:    raw RMSE=0.365688
# Property #0: scaled RMSE=2.437919
# ================
# feature num 0, score = 2.437919
# Property #0:    raw RMSE=0.277047
# Property #0: scaled RMSE=1.846982
# ================
# feature num 0, score = 1.846982
# Property #0:    raw RMSE=0.249704
# Property #0: scaled RMSE=1.664695
# ================
# feature num 0, score = 1.664695
# Property #0:    raw RMSE=0.304034
# Property #0: scaled RMSE=2.026894
# ================
# feature num 0, score = 2.026894
# Property #0:    raw RMSE=0.337417
# Property #0: scaled RMSE=2.249444
# ================
# feature num 0, score = 2.249444
# Property #0:    raw RMSE=0.317059
# Property #0: scaled RMSE=2.113725
# ================
# feature num 0, score = 2.113725
# Property #0:    raw RMSE=0.266333
# Property #0: scaled RMSE=1.775553
# ================
# feature num 0, score = 1.775553
# Property #0:    raw RMSE=0.347097
# Property #0: scaled RMSE=2.313981
# ================
# feature num 0, score = 2.313981
# Property #0:    raw RMSE=0.244050
# Property #0: scaled RMSE=1.626997
# ================
# feature num 0, score = 1.626997
# Property #0:    raw RMSE=0.275920
# Property #0: scaled RMSE=1.839469
# ================
# feature num 0, score = 1.839469
# Property #0:    raw RMSE=0.287343
# Property #0: scaled RMSE=1.915622
# ================
# feature num 0, score = 1.915622
# Property #0:    raw RMSE=0.308219
# Property #0: scaled RMSE=2.054791
# ================
# feature num 0, score = 2.054791
# Property #0:    raw RMSE=0.359552
# Property #0: scaled RMSE=2.397011
# ================
# feature num 0, score = 2.397011
# Property #0:    raw RMSE=0.272374
# Property #0: scaled RMSE=1.815829
# ================
# feature num 0, score = 1.815829
# Property #0:    raw RMSE=0.305178
# Property #0: scaled RMSE=2.034520
# ================
# feature num 0, score = 2.034520
# Property #0:    raw RMSE=0.289637
# Property #0: scaled RMSE=1.930915
# ================
# feature num 0, score = 1.930915
# Property #0:    raw RMSE=0.373352
# Property #0: scaled RMSE=2.489011
# ================
# feature num 0, score = 2.489011
# Property #0:    raw RMSE=0.350815
# Property #0: scaled RMSE=2.338769
# ================
# feature num 0, score = 2.338769
# Property #0:    raw RMSE=0.209383
# Property #0: scaled RMSE=1.395889
# ================
# feature num 0, score = 1.395889
# Property #0:    raw RMSE=0.238419
# Property #0: scaled RMSE=1.589457
# ================
# feature num 0, score = 1.589457
# Property #0:    raw RMSE=0.253678
# Property #0: scaled RMSE=1.691186
# ================
# feature num 0, score = 1.691186
# Property #0:    raw RMSE=0.272558
# Property #0: scaled RMSE=1.817056
# ================
# feature num 0, score = 1.817056
# Property #0:    raw RMSE=0.320232
# Property #0: scaled RMSE=2.134882
# ================
# feature num 0, score = 2.134882
# Property #0:    raw RMSE=0.240946
# Property #0: scaled RMSE=1.606307
# ================
# feature num 0, score = 1.606307
# Property #0:    raw RMSE=0.267019
# Property #0: scaled RMSE=1.780129
# ================
# feature num 0, score = 1.780129
# Property #0:    raw RMSE=0.396154
# Property #0: scaled RMSE=2.641024
# ================
# feature num 0, score = 2.641024
# Property #0:    raw RMSE=0.309892
# Property #0: scaled RMSE=2.065947
# ================
# feature num 0, score = 2.065947
# Property #0:    raw RMSE=0.348765
# Property #0: scaled RMSE=2.325098
# ================
# feature num 0, score = 2.325098
# Property #0:    raw RMSE=0.307075
# Property #0: scaled RMSE=2.047164
# ================
# feature num 0, score = 2.047164
# Property #0:    raw RMSE=0.323410
# Property #0: scaled RMSE=2.156067
# ================
# feature num 0, score = 2.156067
# Property #0:    raw RMSE=0.265285
# Property #0: scaled RMSE=1.768568
# ================
# feature num 0, score = 1.768568
# Property #0:    raw RMSE=0.257797
# Property #0: scaled RMSE=1.718643
# ================
# feature num 0, score = 1.718643
# Property #0:    raw RMSE=0.348479
# Property #0: scaled RMSE=2.323191
# ================
# feature num 0, score = 2.323191
# Property #0:    raw RMSE=0.219548
# Property #0: scaled RMSE=1.463650
# ================
# feature num 0, score = 1.463650
# Property #0:    raw RMSE=0.337940
# Property #0: scaled RMSE=2.252935
# ================
# feature num 0, score = 2.252935
# Property #0:    raw RMSE=0.245800
# Property #0: scaled RMSE=1.638669
# ================
# feature num 0, score = 1.638669
# Property #0:    raw RMSE=0.284602
# Property #0: scaled RMSE=1.897347
# ================
# feature num 0, score = 1.897347
# Property #0:    raw RMSE=0.302447
# Property #0: scaled RMSE=2.016311
# ================
# feature num 0, score = 2.016311
# Property #0:    raw RMSE=0.266738
# Property #0: scaled RMSE=1.778252
# ================
# feature num 0, score = 1.778252
# Property #0:    raw RMSE=0.288379
# Property #0: scaled RMSE=1.922526
# ================
# feature num 0, score = 1.922526
# Property #0:    raw RMSE=0.310993
# Property #0: scaled RMSE=2.073284
# ================
# feature num 0, score = 2.073284
# Property #0:    raw RMSE=0.272375
# Property #0: scaled RMSE=1.815833
# ================
# feature num 0, score = 1.815833
# Property #0:    raw RMSE=0.307132
# Property #0: scaled RMSE=2.047550
# ================
# feature num 0, score = 2.047550
# Property #0:    raw RMSE=0.292867
# Property #0: scaled RMSE=1.952446
# ================
# feature num 0, score = 1.952446
# Property #0:    raw RMSE=0.286130
# Property #0: scaled RMSE=1.907536
# ================
# feature num 0, score = 1.907536
# Property #0:    raw RMSE=0.400947
# Property #0: scaled RMSE=2.672983
# ================
# feature num 0, score = 2.672983
# Property #0:    raw RMSE=0.323225
# Property #0: scaled RMSE=2.154833
# ================
# feature num 0, score = 2.154833
# Property #0:    raw RMSE=0.304706
# Property #0: scaled RMSE=2.031373
# ================
# feature num 0, score = 2.031373
# Property #0:    raw RMSE=0.217828
# Property #0: scaled RMSE=1.452186
# ================
# feature num 0, score = 1.452186
# Property #0:    raw RMSE=0.227636
# Property #0: scaled RMSE=1.517573
# ================
# feature num 0, score = 1.517573
# Property #0:    raw RMSE=0.266649
# Property #0: scaled RMSE=1.777661
# ================
# feature num 0, score = 1.777661
# Property #0:    raw RMSE=0.279096
# Property #0: scaled RMSE=1.860643
# ================
# feature num 0, score = 1.860643
# Property #0:    raw RMSE=0.292352
# Property #0: scaled RMSE=1.949010
# ================
# feature num 0, score = 1.949010
# Property #0:    raw RMSE=0.250833
# Property #0: scaled RMSE=1.672223
# ================
# feature num 0, score = 1.672223
# Property #0:    raw RMSE=0.337384
# Property #0: scaled RMSE=2.249230
# ================
# feature num 0, score = 2.249230
# Property #0:    raw RMSE=0.290436
# Property #0: scaled RMSE=1.936237
# ================
# feature num 0, score = 1.936237
# Property #0:    raw RMSE=0.308298
# Property #0: scaled RMSE=2.055322
# ================
# feature num 0, score = 2.055322
# Property #0:    raw RMSE=0.292884
# Property #0: scaled RMSE=1.952563
# ================
# feature num 0, score = 1.952563
# Property #0:    raw RMSE=0.283949
# Property #0: scaled RMSE=1.892993
# ================
# feature num 0, score = 1.892993
# Property #0:    raw RMSE=0.241455
# Property #0: scaled RMSE=1.609698
# ================
# feature num 0, score = 1.609698
# Property #0:    raw RMSE=0.251908
# Property #0: scaled RMSE=1.679389
# ================
# feature num 0, score = 1.679389
# Property #0:    raw RMSE=0.288750
# Property #0: scaled RMSE=1.925000
# ================
# feature num 0, score = 1.925000
# Property #0:    raw RMSE=0.247764
# Property #0: scaled RMSE=1.651757
# ================
# feature num 0, score = 1.651757
# Property #0:    raw RMSE=0.293516
# Property #0: scaled RMSE=1.956772
# ================
# feature num 0, score = 1.956772
# Property #0:    raw RMSE=0.264693
# Property #0: scaled RMSE=1.764618
# ================
# feature num 0, score = 1.764618
# Property #0:    raw RMSE=0.269069
# Property #0: scaled RMSE=1.793794
# ================
# feature num 0, score = 1.793794
# Property #0:    raw RMSE=0.320028
# Property #0: scaled RMSE=2.133520
# ================
# feature num 0, score = 2.133520
# Property #0:    raw RMSE=0.290511
# Property #0: scaled RMSE=1.936737
# ================
# feature num 0, score = 1.936737
# Property #0:    raw RMSE=0.320236
# Property #0: scaled RMSE=2.134903
# ================
# feature num 0, score = 2.134903
# Property #0:    raw RMSE=0.303647
# Property #0: scaled RMSE=2.024316
# ================
# feature num 0, score = 2.024316
# Property #0:    raw RMSE=0.316109
# Property #0: scaled RMSE=2.107392
# ================
# feature num 0, score = 2.107392
# Property #0:    raw RMSE=0.226268
# Property #0: scaled RMSE=1.508452
# ================
# feature num 0, score = 1.508452
# Property #0:    raw RMSE=0.252277
# Property #0: scaled RMSE=1.681844
# ================
# feature num 0, score = 1.681844
# Property #0:    raw RMSE=0.310304
# Property #0: scaled RMSE=2.068696
# ================
# feature num 0, score = 2.068696
# Property #0:    raw RMSE=0.205586
# Property #0: scaled RMSE=1.370575
# ================
# feature num 0, score = 1.370575
# Property #0:    raw RMSE=0.248160
# Property #0: scaled RMSE=1.654398
# ================
# feature num 0, score = 1.654398
# Property #1:    raw RMSE=0.101459
# Property #1: scaled RMSE=1.268233
# ================
# feature num 1, score = 1.268233
# Property #1:    raw RMSE=0.101464
# Property #1: scaled RMSE=1.268294
# ================
# feature num 1, score = 1.268294
# Property #1:    raw RMSE=0.101318
# Property #1: scaled RMSE=1.266478
# ================
# feature num 1, score = 1.266478
# Property #1:    raw RMSE=0.100816
# Property #1: scaled RMSE=1.260198
# ================
# feature num 1, score = 1.260198
# Property #1:    raw RMSE=0.100620
# Property #1: scaled RMSE=1.257745
# ================
# feature num 1, score = 1.257745
# Property #1:    raw RMSE=0.101272
# Property #1: scaled RMSE=1.265900
# ================
# feature num 1, score = 1.265900
# Property #1:    raw RMSE=0.101952
# Property #1: scaled RMSE=1.274396
# ================
# feature num 1, score = 1.274396
# Property #1:    raw RMSE=0.101016
# Property #1: scaled RMSE=1.262699
# ================
# feature num 1, score = 1.262699
# Property #1:    raw RMSE=0.101111
# Property #1: scaled RMSE=1.263891
# ================
# feature num 1, score = 1.263891
# Property #1:    raw RMSE=0.101827
# Property #1: scaled RMSE=1.272840
# ================
# feature num 1, score = 1.272840
# Property #1:    raw RMSE=0.100026
# Property #1: scaled RMSE=1.250329
# ================
# feature num 1, score = 1.250329
# Property #1:    raw RMSE=0.100886
# Property #1: scaled RMSE=1.261075
# ================
# feature num 1, score = 1.261075
# Property #1:    raw RMSE=0.102065
# Property #1: scaled RMSE=1.275806
# ================
# feature num 1, score = 1.275806
# Property #1:    raw RMSE=0.101232
# Property #1: scaled RMSE=1.265400
# ================
# feature num 1, score = 1.265400
# Property #1:    raw RMSE=0.102227
# Property #1: scaled RMSE=1.277832
# ================
# feature num 1, score = 1.277832
# Property #1:    raw RMSE=0.100505
# Property #1: scaled RMSE=1.256307
# ================
# feature num 1, score = 1.256307
# Property #1:    raw RMSE=0.100414
# Property #1: scaled RMSE=1.255179
# ================
# feature num 1, score = 1.255179
# Property #1:    raw RMSE=0.101122
# Property #1: scaled RMSE=1.264025
# ================
# feature num 1, score = 1.264025
# Property #1:    raw RMSE=0.101241
# Property #1: scaled RMSE=1.265512
# ================
# feature num 1, score = 1.265512
# Property #1:    raw RMSE=0.101499
# Property #1: scaled RMSE=1.268733
# ================
# feature num 1, score = 1.268733
# Property #1:    raw RMSE=0.103382
# Property #1: scaled RMSE=1.292280
# ================
# feature num 1, score = 1.292280
# Property #1:    raw RMSE=0.101104
# Property #1: scaled RMSE=1.263794
# ================
# feature num 1, score = 1.263794
# Property #1:    raw RMSE=0.100473
# Property #1: scaled RMSE=1.255908
# ================
# feature num 1, score = 1.255908
# Property #1:    raw RMSE=0.101532
# Property #1: scaled RMSE=1.269147
# ================
# feature num 1, score = 1.269147
# Property #1:    raw RMSE=0.101375
# Property #1: scaled RMSE=1.267183
# ================
# feature num 1, score = 1.267183
# Property #1:    raw RMSE=0.100731
# Property #1: scaled RMSE=1.259135
# ================
# feature num 1, score = 1.259135
# Property #1:    raw RMSE=0.100940
# Property #1: scaled RMSE=1.261745
# ================
# feature num 1, score = 1.261745
# Property #1:    raw RMSE=0.100490
# Property #1: scaled RMSE=1.256127
# ================
# feature num 1, score = 1.256127
# Property #1:    raw RMSE=0.100295
# Property #1: scaled RMSE=1.253682
# ================
# feature num 1, score = 1.253682
# Property #1:    raw RMSE=0.101844
# Property #1: scaled RMSE=1.273050
# ================
# feature num 1, score = 1.273050
# Property #1:    raw RMSE=0.101124
# Property #1: scaled RMSE=1.264046
# ================
# feature num 1, score = 1.264046
# Property #1:    raw RMSE=0.100386
# Property #1: scaled RMSE=1.254822
# ================
# feature num 1, score = 1.254822
# Property #1:    raw RMSE=0.102444
# Property #1: scaled RMSE=1.280552
# ================
# feature num 1, score = 1.280552
# Property #1:    raw RMSE=0.101786
# Property #1: scaled RMSE=1.272324
# ================
# feature num 1, score = 1.272324
# Property #1:    raw RMSE=0.101273
# Property #1: scaled RMSE=1.265911
# ================
# feature num 1, score = 1.265911
# Property #1:    raw RMSE=0.101425
# Property #1: scaled RMSE=1.267818
# ================
# feature num 1, score = 1.267818
# Property #1:    raw RMSE=0.101740
# Property #1: scaled RMSE=1.271751
# ================
# feature num 1, score = 1.271751
# Property #1:    raw RMSE=0.101686
# Property #1: scaled RMSE=1.271069
# ================
# feature num 1, score = 1.271069
# Property #1:    raw RMSE=0.101055
# Property #1: scaled RMSE=1.263191
# ================
# feature num 1, score = 1.263191
# Property #1:    raw RMSE=0.101933
# Property #1: scaled RMSE=1.274157
# ================
# feature num 1, score = 1.274157
# Property #1:    raw RMSE=0.101950
# Property #1: scaled RMSE=1.274380
# ================
# feature num 1, score = 1.274380
# Property #1:    raw RMSE=0.101444
# Property #1: scaled RMSE=1.268049
# ================
# feature num 1, score = 1.268049
# Property #1:    raw RMSE=0.101927
# Property #1: scaled RMSE=1.274094
# ================
# feature num 1, score = 1.274094
# Property #1:    raw RMSE=0.101706
# Property #1: scaled RMSE=1.271330
# ================
# feature num 1, score = 1.271330
# Property #1:    raw RMSE=0.101796
# Property #1: scaled RMSE=1.272453
# ================
# feature num 1, score = 1.272453
# Property #1:    raw RMSE=0.101879
# Property #1: scaled RMSE=1.273483
# ================
# feature num 1, score = 1.273483
# Property #1:    raw RMSE=0.101718
# Property #1: scaled RMSE=1.271477
# ================
# feature num 1, score = 1.271477
# Property #1:    raw RMSE=0.101501
# Property #1: scaled RMSE=1.268765
# ================
# feature num 1, score = 1.268765
# Property #1:    raw RMSE=0.101201
# Property #1: scaled RMSE=1.265011
# ================
# feature num 1, score = 1.265011
# Property #1:    raw RMSE=0.101056
# Property #1: scaled RMSE=1.263201
# ================
# feature num 1, score = 1.263201
# Property #1:    raw RMSE=0.102192
# Property #1: scaled RMSE=1.277395
# ================
# feature num 1, score = 1.277395
# Property #1:    raw RMSE=0.102228
# Property #1: scaled RMSE=1.277855
# ================
# feature num 1, score = 1.277855
# Property #1:    raw RMSE=0.101028
# Property #1: scaled RMSE=1.262844
# ================
# feature num 1, score = 1.262844
# Property #1:    raw RMSE=0.101257
# Property #1: scaled RMSE=1.265713
# ================
# feature num 1, score = 1.265713
# Property #1:    raw RMSE=0.100838
# Property #1: scaled RMSE=1.260478
# ================
# feature num 1, score = 1.260478
# Property #1:    raw RMSE=0.101695
# Property #1: scaled RMSE=1.271192
# ================
# feature num 1, score = 1.271192
# Property #1:    raw RMSE=0.101824
# Property #1: scaled RMSE=1.272795
# ================
# feature num 1, score = 1.272795
# Property #1:    raw RMSE=0.101633
# Property #1: scaled RMSE=1.270408
# ================
# feature num 1, score = 1.270408
# Property #1:    raw RMSE=0.100879
# Property #1: scaled RMSE=1.260988
# ================
# feature num 1, score = 1.260988
# Property #1:    raw RMSE=0.101214
# Property #1: scaled RMSE=1.265180
# ================
# feature num 1, score = 1.265180
# Property #1:    raw RMSE=0.100248
# Property #1: scaled RMSE=1.253098
# ================
# feature num 1, score = 1.253098
# Property #1:    raw RMSE=0.100757
# Property #1: scaled RMSE=1.259463
# ================
# feature num 1, score = 1.259463
# Property #1:    raw RMSE=0.100291
# Property #1: scaled RMSE=1.253639
# ================
# feature num 1, score = 1.253639
# Property #1:    raw RMSE=0.100421
# Property #1: scaled RMSE=1.255267
# ================
# feature num 1, score = 1.255267
# Property #1:    raw RMSE=0.100301
# Property #1: scaled RMSE=1.253764
# ================
# feature num 1, score = 1.253764
# Property #1:    raw RMSE=0.100729
# Property #1: scaled RMSE=1.259116
# ================
# feature num 1, score = 1.259116
# Property #1:    raw RMSE=0.100760
# Property #1: scaled RMSE=1.259500
# ================
# feature num 1, score = 1.259500
# Property #1:    raw RMSE=0.100935
# Property #1: scaled RMSE=1.261684
# ================
# feature num 1, score = 1.261684
# Property #1:    raw RMSE=0.101119
# Property #1: scaled RMSE=1.263982
# ================
# feature num 1, score = 1.263982
# Property #1:    raw RMSE=0.103040
# Property #1: scaled RMSE=1.288003
# ================
# feature num 1, score = 1.288003
# Property #1:    raw RMSE=0.103198
# Property #1: scaled RMSE=1.289979
# ================
# feature num 1, score = 1.289979
# Property #1:    raw RMSE=0.102344
# Property #1: scaled RMSE=1.279304
# ================
# feature num 1, score = 1.279304
# Property #1:    raw RMSE=0.100041
# Property #1: scaled RMSE=1.250509
# ================
# feature num 1, score = 1.250509
# Property #1:    raw RMSE=0.099996
# Property #1: scaled RMSE=1.249946
# ================
# feature num 1, score = 1.249946
# Property #1:    raw RMSE=0.101664
# Property #1: scaled RMSE=1.270799
# ================
# feature num 1, score = 1.270799
# Property #1:    raw RMSE=0.100296
# Property #1: scaled RMSE=1.253701
# ================
# feature num 1, score = 1.253701
# Property #1:    raw RMSE=0.100509
# Property #1: scaled RMSE=1.256358
# ================
# feature num 1, score = 1.256358
# Property #1:    raw RMSE=0.100862
# Property #1: scaled RMSE=1.260776
# ================
# feature num 1, score = 1.260776
# Property #1:    raw RMSE=0.101048
# Property #1: scaled RMSE=1.263100
# ================
# feature num 1, score = 1.263100
# Property #1:    raw RMSE=0.101529
# Property #1: scaled RMSE=1.269115
# ================
# feature num 1, score = 1.269115
# Property #1:    raw RMSE=0.100980
# Property #1: scaled RMSE=1.262251
# ================
# feature num 1, score = 1.262251
# Property #1:    raw RMSE=0.100747
# Property #1: scaled RMSE=1.259343
# ================
# feature num 1, score = 1.259343
# Property #1:    raw RMSE=0.100075
# Property #1: scaled RMSE=1.250934
# ================
# feature num 1, score = 1.250934
# Property #1:    raw RMSE=0.100433
# Property #1: scaled RMSE=1.255406
# ================
# feature num 1, score = 1.255406
# Property #1:    raw RMSE=0.101132
# Property #1: scaled RMSE=1.264148
# ================
# feature num 1, score = 1.264148
# Property #1:    raw RMSE=0.101345
# Property #1: scaled RMSE=1.266817
# ================
# feature num 1, score = 1.266817
# Property #1:    raw RMSE=0.101992
# Property #1: scaled RMSE=1.274901
# ================
# feature num 1, score = 1.274901
# Property #1:    raw RMSE=0.100534
# Property #1: scaled RMSE=1.256670
# ================
# feature num 1, score = 1.256670
# Property #1:    raw RMSE=0.101540
# Property #1: scaled RMSE=1.269251
# ================
# feature num 1, score = 1.269251
# Property #1:    raw RMSE=0.099974
# Property #1: scaled RMSE=1.249679
# ================
# feature num 1, score = 1.249679
# Property #1:    raw RMSE=0.101357
# Property #1: scaled RMSE=1.266966
# ================
# feature num 1, score = 1.266966
# Property #1:    raw RMSE=0.101004
# Property #1: scaled RMSE=1.262545
# ================
# feature num 1, score = 1.262545
# Property #1:    raw RMSE=0.100938
# Property #1: scaled RMSE=1.261723
# ================
# feature num 1, score = 1.261723
# Property #1:    raw RMSE=0.101804
# Property #1: scaled RMSE=1.272553
# ================
# feature num 1, score = 1.272553
# Property #1:    raw RMSE=0.102422
# Property #1: scaled RMSE=1.280271
# ================
# feature num 1, score = 1.280271
# Property #1:    raw RMSE=0.101099
# Property #1: scaled RMSE=1.263736
# ================
# feature num 1, score = 1.263736
# Property #1:    raw RMSE=0.100607
# Property #1: scaled RMSE=1.257590
# ================
# feature num 1, score = 1.257590
# Property #1:    raw RMSE=0.100730
# Property #1: scaled RMSE=1.259127
# ================
# feature num 1, score = 1.259127
# Property #1:    raw RMSE=0.101484
# Property #1: scaled RMSE=1.268554
# ================
# feature num 1, score = 1.268554
# Property #1:    raw RMSE=0.100167
# Property #1: scaled RMSE=1.252092
# ================
# feature num 1, score = 1.252092
# Property #1:    raw RMSE=0.100564
# Property #1: scaled RMSE=1.257047
# ================
# feature num 1, score = 1.257047
# Property #1:    raw RMSE=0.100324
# Property #1: scaled RMSE=1.254051
# ================
# feature num 1, score = 1.254051
# Property #1:    raw RMSE=0.100700
# Property #1: scaled RMSE=1.258752
# ================
# feature num 1, score = 1.258752
# Property #1:    raw RMSE=0.101425
# Property #1: scaled RMSE=1.267810
# ================
# feature num 1, score = 1.267810
# Property #1:    raw RMSE=0.100860
# Property #1: scaled RMSE=1.260750
# ================
# feature num 1, score = 1.260750
# Property #1:    raw RMSE=0.100573
# Property #1: scaled RMSE=1.257163
# ================
# feature num 1, score = 1.257163
# Property #1:    raw RMSE=0.100284
# Property #1: scaled RMSE=1.253550
# ================
# feature num 1, score = 1.253550
# Property #1:    raw RMSE=0.101428
# Property #1: scaled RMSE=1.267854
# ================
# feature num 1, score = 1.267854
# Property #1:    raw RMSE=0.100954
# Property #1: scaled RMSE=1.261922
# ================
# feature num 1, score = 1.261922
# Property #1:    raw RMSE=0.101865
# Property #1: scaled RMSE=1.273308
# ================
# feature num 1, score = 1.273308
# Property #1:    raw RMSE=0.100405
# Property #1: scaled RMSE=1.255061
# ================
# feature num 1, score = 1.255061
# Property #1:    raw RMSE=0.100499
# Property #1: scaled RMSE=1.256233
# ================
# feature num 1, score = 1.256233
# Property #1:    raw RMSE=0.100901
# Property #1: scaled RMSE=1.261264
# ================
# feature num 1, score = 1.261264
# Property #1:    raw RMSE=0.101074
# Property #1: scaled RMSE=1.263425
# ================
# feature num 1, score = 1.263425
# Property #1:    raw RMSE=0.114774
# Property #1: scaled RMSE=1.434673
# ================
# feature num 1, score = 1.434673
# Property #1:    raw RMSE=0.102056
# Property #1: scaled RMSE=1.275705
# ================
# feature num 1, score = 1.275705
# Property #1:    raw RMSE=0.100782
# Property #1: scaled RMSE=1.259773
# ================
# feature num 1, score = 1.259773
# Property #1:    raw RMSE=0.101110
# Property #1: scaled RMSE=1.263878
# ================
# feature num 1, score = 1.263878
# Property #1:    raw RMSE=0.100987
# Property #1: scaled RMSE=1.262340
# ================
# feature num 1, score = 1.262340
# Property #1:    raw RMSE=0.100974
# Property #1: scaled RMSE=1.262180
# ================
# feature num 1, score = 1.262180
# Property #1:    raw RMSE=0.101338
# Property #1: scaled RMSE=1.266724
# ================
# feature num 1, score = 1.266724
# Property #1:    raw RMSE=0.101060
# Property #1: scaled RMSE=1.263251
# ================
# feature num 1, score = 1.263251
# Property #1:    raw RMSE=0.100828
# Property #1: scaled RMSE=1.260349
# ================
# feature num 1, score = 1.260349
# Property #1:    raw RMSE=0.101307
# Property #1: scaled RMSE=1.266341
# ================
# feature num 1, score = 1.266341
# Property #1:    raw RMSE=0.100780
# Property #1: scaled RMSE=1.259749
# ================
# feature num 1, score = 1.259749
# Property #1:    raw RMSE=0.100780
# Property #1: scaled RMSE=1.259747
# ================
# feature num 1, score = 1.259747
# Property #1:    raw RMSE=0.099386
# Property #1: scaled RMSE=1.242330
# ================
# feature num 1, score = 1.242330
# Property #1:    raw RMSE=0.100229
# Property #1: scaled RMSE=1.252869
# ================
# feature num 1, score = 1.252869
# Property #1:    raw RMSE=0.101028
# Property #1: scaled RMSE=1.262854
# ================
# feature num 1, score = 1.262854
# Property #1:    raw RMSE=0.100458
# Property #1: scaled RMSE=1.255730
# ================
# feature num 1, score = 1.255730
# Property #1:    raw RMSE=0.100565
# Property #1: scaled RMSE=1.257057
# ================
# feature num 1, score = 1.257057
# Property #1:    raw RMSE=0.101156
# Property #1: scaled RMSE=1.264445
# ================
# feature num 1, score = 1.264445
# Property #1:    raw RMSE=0.100830
# Property #1: scaled RMSE=1.260377
# ================
# feature num 1, score = 1.260377
# Property #1:    raw RMSE=0.101192
# Property #1: scaled RMSE=1.264895
# ================
# feature num 1, score = 1.264895
# Property #1:    raw RMSE=0.101864
# Property #1: scaled RMSE=1.273298
# ================
# feature num 1, score = 1.273298
# Property #1:    raw RMSE=0.100746
# Property #1: scaled RMSE=1.259330
# ================
# feature num 1, score = 1.259330
# Property #1:    raw RMSE=0.100067
# Property #1: scaled RMSE=1.250833
# ================
# feature num 1, score = 1.250833
# Property #1:    raw RMSE=0.102082
# Property #1: scaled RMSE=1.276031
# ================
# feature num 1, score = 1.276031
# Property #1:    raw RMSE=0.100796
# Property #1: scaled RMSE=1.259948
# ================
# feature num 1, score = 1.259948
# Property #1:    raw RMSE=0.100815
# Property #1: scaled RMSE=1.260183
# ================
# feature num 1, score = 1.260183
# Property #1:    raw RMSE=0.101673
# Property #1: scaled RMSE=1.270910
# ================
# feature num 1, score = 1.270910
# Property #1:    raw RMSE=0.100729
# Property #1: scaled RMSE=1.259118
# ================
# feature num 1, score = 1.259118
# Property #1:    raw RMSE=0.100894
# Property #1: scaled RMSE=1.261176
# ================
# feature num 1, score = 1.261176
# Property #1:    raw RMSE=0.099879
# Property #1: scaled RMSE=1.248484
# ================
# feature num 1, score = 1.248484
# Property #1:    raw RMSE=0.102177
# Property #1: scaled RMSE=1.277211
# ================
# feature num 1, score = 1.277211
# Property #1:    raw RMSE=0.101287
# Property #1: scaled RMSE=1.266092
# ================
# feature num 1, score = 1.266092
# Property #1:    raw RMSE=0.101089
# Property #1: scaled RMSE=1.263611
# ================
# feature num 1, score = 1.263611
# Property #1:    raw RMSE=0.101732
# Property #1: scaled RMSE=1.271651
# ================
# feature num 1, score = 1.271651
# Property #1:    raw RMSE=0.100792
# Property #1: scaled RMSE=1.259906
# ================
# feature num 1, score = 1.259906
# Property #1:    raw RMSE=0.100110
# Property #1: scaled RMSE=1.251378
# ================
# feature num 1, score = 1.251378
# Property #1:    raw RMSE=0.101080
# Property #1: scaled RMSE=1.263497
# ================
# feature num 1, score = 1.263497
# Property #1:    raw RMSE=0.101181
# Property #1: scaled RMSE=1.264761
# ================
# feature num 1, score = 1.264761
# Property #1:    raw RMSE=0.101669
# Property #1: scaled RMSE=1.270868
# ================
# feature num 1, score = 1.270868
# Property #1:    raw RMSE=0.101309
# Property #1: scaled RMSE=1.266368
# ================
# feature num 1, score = 1.266368
# Property #1:    raw RMSE=0.101666
# Property #1: scaled RMSE=1.270827
# ================
# feature num 1, score = 1.270827
# Property #1:    raw RMSE=0.101305
# Property #1: scaled RMSE=1.266307
# ================
# feature num 1, score = 1.266307
# Property #1:    raw RMSE=0.101215
# Property #1: scaled RMSE=1.265186
# ================
# feature num 1, score = 1.265186
# Property #1:    raw RMSE=0.101034
# Property #1: scaled RMSE=1.262922
# ================
# feature num 1, score = 1.262922
# Property #1:    raw RMSE=0.101589
# Property #1: scaled RMSE=1.269867
# ================
# feature num 1, score = 1.269867
# Property #1:    raw RMSE=0.101218
# Property #1: scaled RMSE=1.265227
# ================
# feature num 1, score = 1.265227
# Property #1:    raw RMSE=0.101622
# Property #1: scaled RMSE=1.270274
# ================
# feature num 1, score = 1.270274
# Property #1:    raw RMSE=0.100941
# Property #1: scaled RMSE=1.261768
# ================
# feature num 1, score = 1.261768
# Property #1:    raw RMSE=0.101290
# Property #1: scaled RMSE=1.266119
# ================
# feature num 1, score = 1.266119
# Property #1:    raw RMSE=0.100896
# Property #1: scaled RMSE=1.261195
# ================
# feature num 1, score = 1.261195
# Property #1:    raw RMSE=0.101785
# Property #1: scaled RMSE=1.272312
# ================
# feature num 1, score = 1.272312
# Property #1:    raw RMSE=0.100612
# Property #1: scaled RMSE=1.257656
# ================
# feature num 1, score = 1.257656
# Property #1:    raw RMSE=0.101472
# Property #1: scaled RMSE=1.268400
# ================
# feature num 1, score = 1.268400
# Property #1:    raw RMSE=0.100575
# Property #1: scaled RMSE=1.257193
# ================
# feature num 1, score = 1.257193
# Property #1:    raw RMSE=0.101076
# Property #1: scaled RMSE=1.263444
# ================
# feature num 1, score = 1.263444
# Property #1:    raw RMSE=0.100363
# Property #1: scaled RMSE=1.254538
# ================
# feature num 1, score = 1.254538
# Property #1:    raw RMSE=0.100773
# Property #1: scaled RMSE=1.259663
# ================
# feature num 1, score = 1.259663
# Property #1:    raw RMSE=0.101292
# Property #1: scaled RMSE=1.266146
# ================
# feature num 1, score = 1.266146
# Property #1:    raw RMSE=0.100758
# Property #1: scaled RMSE=1.259474
# ================
# feature num 1, score = 1.259474
# Property #1:    raw RMSE=0.100441
# Property #1: scaled RMSE=1.255518
# ================
# feature num 1, score = 1.255518
# Property #1:    raw RMSE=0.101563
# Property #1: scaled RMSE=1.269534
# ================
# feature num 1, score = 1.269534
# Property #1:    raw RMSE=0.101585
# Property #1: scaled RMSE=1.269812
# ================
# feature num 1, score = 1.269812
# Property #1:    raw RMSE=0.101233
# Property #1: scaled RMSE=1.265410
# ================
# feature num 1, score = 1.265410
# Property #1:    raw RMSE=0.101611
# Property #1: scaled RMSE=1.270138
# ================
# feature num 1, score = 1.270138
# Property #1:    raw RMSE=0.101708
# Property #1: scaled RMSE=1.271350
# ================
# feature num 1, score = 1.271350
# Property #1:    raw RMSE=0.101447
# Property #1: scaled RMSE=1.268084
# ================
# feature num 1, score = 1.268084
# Property #1:    raw RMSE=0.101403
# Property #1: scaled RMSE=1.267539
# ================
# feature num 1, score = 1.267539
# Property #1:    raw RMSE=0.100682
# Property #1: scaled RMSE=1.258528
# ================
# feature num 1, score = 1.258528
# Property #1:    raw RMSE=0.101235
# Property #1: scaled RMSE=1.265442
# ================
# feature num 1, score = 1.265442
# Property #1:    raw RMSE=0.101255
# Property #1: scaled RMSE=1.265686
# ================
# feature num 1, score = 1.265686
# Property #1:    raw RMSE=0.099930
# Property #1: scaled RMSE=1.249125
# ================
# feature num 1, score = 1.249125
# Property #1:    raw RMSE=0.100680
# Property #1: scaled RMSE=1.258498
# ================
# feature num 1, score = 1.258498
# Property #1:    raw RMSE=0.100812
# Property #1: scaled RMSE=1.260155
# ================
# feature num 1, score = 1.260155
# Property #1:    raw RMSE=0.101781
# Property #1: scaled RMSE=1.272261
# ================
# feature num 1, score = 1.272261
# Property #1:    raw RMSE=0.100459
# Property #1: scaled RMSE=1.255732
# ================
# feature num 1, score = 1.255732
# Property #1:    raw RMSE=0.100927
# Property #1: scaled RMSE=1.261593
# ================
# feature num 1, score = 1.261593
# Property #1:    raw RMSE=0.100786
# Property #1: scaled RMSE=1.259823
# ================
# feature num 1, score = 1.259823
# Property #1:    raw RMSE=0.101594
# Property #1: scaled RMSE=1.269922
# ================
# feature num 1, score = 1.269922
# Property #1:    raw RMSE=0.100785
# Property #1: scaled RMSE=1.259810
# ================
# feature num 1, score = 1.259810
# Property #1:    raw RMSE=0.100442
# Property #1: scaled RMSE=1.255522
# ================
# feature num 1, score = 1.255522
# Property #1:    raw RMSE=0.100926
# Property #1: scaled RMSE=1.261576
# ================
# feature num 1, score = 1.261576
# Property #1:    raw RMSE=0.101384
# Property #1: scaled RMSE=1.267300
# ================
# feature num 1, score = 1.267300
# Property #1:    raw RMSE=0.100312
# Property #1: scaled RMSE=1.253906
# ================
# feature num 1, score = 1.253906
# Property #1:    raw RMSE=0.100446
# Property #1: scaled RMSE=1.255569
# ================
# feature num 1, score = 1.255569
# Property #1:    raw RMSE=0.100642
# Property #1: scaled RMSE=1.258020
# ================
# feature num 1, score = 1.258020
# Property #1:    raw RMSE=0.101051
# Property #1: scaled RMSE=1.263137
# ================
# feature num 1, score = 1.263137
# Property #2:    raw RMSE=1.994640
# Property #2: scaled RMSE=1.994640
# ================
# feature num 2, score = 1.994640
# Property #2:    raw RMSE=1.693321
# Property #2: scaled RMSE=1.693321
# ================
# feature num 2, score = 1.693321
# Property #2:    raw RMSE=1.923701
# Property #2: scaled RMSE=1.923701
# ================
# feature num 2, score = 1.923701
# Property #2:    raw RMSE=1.490192
# Property #2: scaled RMSE=1.490192
# ================
# feature num 2, score = 1.490192
# Property #2:    raw RMSE=1.558842
# Property #2: scaled RMSE=1.558842
# ================
# feature num 2, score = 1.558842
# Property #2:    raw RMSE=2.097320
# Property #2: scaled RMSE=2.097320
# ================
# feature num 2, score = 2.097320
# Property #2:    raw RMSE=1.543215
# Property #2: scaled RMSE=1.543215
# ================
# feature num 2, score = 1.543215
# Property #2:    raw RMSE=1.330886
# Property #2: scaled RMSE=1.330886
# ================
# feature num 2, score = 1.330886
# Property #2:    raw RMSE=1.315021
# Property #2: scaled RMSE=1.315021
# ================
# feature num 2, score = 1.315021
# Property #2:    raw RMSE=1.719593
# Property #2: scaled RMSE=1.719593
# ================
# feature num 2, score = 1.719593
# ...
# Property #2: scaled RMSE=1.739912
# ================
# feature num 2, score = 1.739912
# Property #2:    raw RMSE=1.632765
# Property #2: scaled RMSE=1.632765
# ================
# feature num 2, score = 1.632765
# Property #2:    raw RMSE=1.665525
# Property #2: scaled RMSE=1.665525
# ================
# feature num 2, score = 1.665525
# Property #2:    raw RMSE=1.950959
# Property #2: scaled RMSE=1.950959
# ================
# feature num 2, score = 1.950959
# Property #2:    raw RMSE=1.353077
# Property #2: scaled RMSE=1.353077
# ================
# feature num 2, score = 1.353077
# Property #2:    raw RMSE=1.517086
# Property #2: scaled RMSE=1.517086
# ================
# feature num 2, score = 1.517086
# Property #2:    raw RMSE=1.608545
# Property #2: scaled RMSE=1.608545
# ================
# feature num 2, score = 1.608545
# Property #2:    raw RMSE=1.494525
# Property #2: scaled RMSE=1.494525
# ================
# feature num 2, score = 1.494525
# Property #2:    raw RMSE=1.686831
# Property #2: scaled RMSE=1.686831
# ================
# feature num 2, score = 1.686831
# Property #2:    raw RMSE=1.812824
# Property #2: scaled RMSE=1.812824
# ================
# feature num 2, score = 1.812824
# Property #2:    raw RMSE=1.572016
# Property #2: scaled RMSE=1.572016
# ================
# feature num 2, score = 1.572016
# Property #2:    raw RMSE=1.926282
# Property #2: scaled RMSE=1.926282
# ================
# feature num 2, score = 1.926282
# Property #2:    raw RMSE=2.125563
# Property #2: scaled RMSE=2.125563
# ================
# feature num 2, score = 2.125563
# Property #2:    raw RMSE=1.735562
# Property #2: scaled RMSE=1.735562
# ================
# feature num 2, score = 1.735562
# Property #2:    raw RMSE=1.490298
# Property #2: scaled RMSE=1.490298
# ================
# feature num 2, score = 1.490298
# Property #2:    raw RMSE=1.873923
# Property #2: scaled RMSE=1.873923
# ================
# feature num 2, score = 1.873923
# Property #2:    raw RMSE=1.554042
# Property #2: scaled RMSE=1.554042
# ================
# feature num 2, score = 1.554042
# Property #2:    raw RMSE=1.395121
# Property #2: scaled RMSE=1.395121
# ================
# feature num 2, score = 1.395121
# Property #2:    raw RMSE=1.966572
# Property #2: scaled RMSE=1.966572
# ================
# feature num 2, score = 1.966572
# Property #2:    raw RMSE=1.269398
# Property #2: scaled RMSE=1.269398
# ================
# feature num 2, score = 1.269398
# Property #2:    raw RMSE=1.599890
# Property #2: scaled RMSE=1.599890
# ================
# feature num 2, score = 1.599890
# Property #2:    raw RMSE=1.673391
# Property #2: scaled RMSE=1.673391
# ================
# feature num 2, score = 1.673391
# Property #2:    raw RMSE=1.438282
# Property #2: scaled RMSE=1.438282
# ================
# feature num 2, score = 1.438282
# Property #2:    raw RMSE=1.937611
# Property #2: scaled RMSE=1.937611
# ================
# feature num 2, score = 1.937611
# Property #2:    raw RMSE=1.996069
# Property #2: scaled RMSE=1.996069
# ================
# feature num 2, score = 1.996069
# Property #2:    raw RMSE=1.825580
# Property #2: scaled RMSE=1.825580
# ================
# feature num 2, score = 1.825580
# Property #2:    raw RMSE=1.710812
# Property #2: scaled RMSE=1.710812
# ================
# feature num 2, score = 1.710812
# Property #2:    raw RMSE=1.580488
# Property #2: scaled RMSE=1.580488
# ================
# feature num 2, score = 1.580488
# Property #2:    raw RMSE=1.341603
# Property #2: scaled RMSE=1.341603
# ================
# feature num 2, score = 1.341603
# Property #2:    raw RMSE=1.195605
# Property #2: scaled RMSE=1.195605
# ================
# feature num 2, score = 1.195605
# Property #2:    raw RMSE=1.598708
# Property #2: scaled RMSE=1.598708
# ================
# feature num 2, score = 1.598708
# Property #2:    raw RMSE=1.532109
# Property #2: scaled RMSE=1.532109
# ================
# feature num 2, score = 1.532109
# Property #2:    raw RMSE=1.840306
# Property #2: scaled RMSE=1.840306
# ================
# feature num 2, score = 1.840306
# Property #2:    raw RMSE=2.462505
# Property #2: scaled RMSE=2.462505
# ================
# feature num 2, score = 2.462505
# Property #2:    raw RMSE=2.179411
# Property #2: scaled RMSE=2.179411
# ================
# feature num 2, score = 2.179411
# Property #2:    raw RMSE=1.973966
# Property #2: scaled RMSE=1.973966
# ================
# feature num 2, score = 1.973966
# Property #2:    raw RMSE=1.898158
# Property #2: scaled RMSE=1.898158
# ================
# feature num 2, score = 1.898158
# Property #2:    raw RMSE=1.986464
# Property #2: scaled RMSE=1.986464
# ================
# feature num 2, score = 1.986464
# Property #2:    raw RMSE=1.712638
# Property #2: scaled RMSE=1.712638
# ================
# feature num 2, score = 1.712638
# Property #2:    raw RMSE=2.060665
# Property #2: scaled RMSE=2.060665
# ================
# feature num 2, score = 2.060665
# Property #2:    raw RMSE=1.625056
# Property #2: scaled RMSE=1.625056
# ================
# feature num 2, score = 1.625056
# Property #2:    raw RMSE=2.004031
# Property #2: scaled RMSE=2.004031
# ================
# feature num 2, score = 2.004031
# Property #2:    raw RMSE=1.729216
# Property #2: scaled RMSE=1.729216
# ================
# feature num 2, score = 1.729216
# Property #2:    raw RMSE=1.643520
# Property #2: scaled RMSE=1.643520
# ================
# feature num 2, score = 1.643520
# Property #2:    raw RMSE=1.572275
# Property #2: scaled RMSE=1.572275
# ================
# feature num 2, score = 1.572275
# Property #2:    raw RMSE=1.914468
# Property #2: scaled RMSE=1.914468
# ================
# feature num 2, score = 1.914468
# Property #2:    raw RMSE=1.669096
# Property #2: scaled RMSE=1.669096
# ================
# feature num 2, score = 1.669096
# Property #2:    raw RMSE=1.961399
# Property #2: scaled RMSE=1.961399
# ================
# feature num 2, score = 1.961399
# Property #2:    raw RMSE=1.947928
# Property #2: scaled RMSE=1.947928
# ================
# feature num 2, score = 1.947928
# Property #2:    raw RMSE=1.463171
# Property #2: scaled RMSE=1.463171
# ================
# feature num 2, score = 1.463171
# Property #2:    raw RMSE=2.044198
# Property #2: scaled RMSE=2.044198
# ================
# feature num 2, score = 2.044198
# Property #2:    raw RMSE=1.851936
# Property #2: scaled RMSE=1.851936
# ================
# feature num 2, score = 1.851936
# Property #2:    raw RMSE=1.431724
# Property #2: scaled RMSE=1.431724
# ================
# feature num 2, score = 1.431724
# Property #2:    raw RMSE=1.902655
# Property #2: scaled RMSE=1.902655
# ================
# feature num 2, score = 1.902655
# Property #2:    raw RMSE=1.950850
# Property #2: scaled RMSE=1.950850
# ================
# feature num 2, score = 1.950850
# Property #2:    raw RMSE=1.655697
# Property #2: scaled RMSE=1.655697
# ================
# feature num 2, score = 1.655697
# Property #2:    raw RMSE=1.913314
# Property #2: scaled RMSE=1.913314
# ================
# feature num 2, score = 1.913314
# Property #2:    raw RMSE=2.005544
# Property #2: scaled RMSE=2.005544
# ================
# feature num 2, score = 2.005544
# Property #2:    raw RMSE=1.879045
# Property #2: scaled RMSE=1.879045
# ================
# feature num 2, score = 1.879045
# Property #2:    raw RMSE=1.695176
# Property #2: scaled RMSE=1.695176
# ================
# feature num 2, score = 1.695176
# Property #2:    raw RMSE=1.947158
# Property #2: scaled RMSE=1.947158
# ================
# feature num 2, score = 1.947158
# Property #2:    raw RMSE=1.425220
# Property #2: scaled RMSE=1.425220
# ================
# feature num 2, score = 1.425220
# Property #2:    raw RMSE=1.853507
# Property #2: scaled RMSE=1.853507
# ================
# feature num 2, score = 1.853507
# Property #2:    raw RMSE=1.465121
# Property #2: scaled RMSE=1.465121
# ================
# feature num 2, score = 1.465121
# Property #2:    raw RMSE=1.512062
# Property #2: scaled RMSE=1.512062
# ================
# feature num 2, score = 1.512062
# Property #2:    raw RMSE=1.592274
# Property #2: scaled RMSE=1.592274
# ================
# feature num 2, score = 1.592274
# Property #2:    raw RMSE=1.842702
# Property #2: scaled RMSE=1.842702
# ================
# feature num 2, score = 1.842702
# Property #2:    raw RMSE=2.075848
# Property #2: scaled RMSE=2.075848
# ================
# feature num 2, score = 2.075848
# Property #2:    raw RMSE=1.103868
# Property #2: scaled RMSE=1.103868
# ================
# feature num 2, score = 1.103868
# Property #2:    raw RMSE=1.737897
# Property #2: scaled RMSE=1.737897
# ================
# feature num 2, score = 1.737897
# Property #2:    raw RMSE=1.489536
# Property #2: scaled RMSE=1.489536
# ================
# feature num 2, score = 1.489536
# Property #2:    raw RMSE=1.582624
# Property #2: scaled RMSE=1.582624
# ================
# feature num 2, score = 1.582624
# Property #2:    raw RMSE=2.355436
# Property #2: scaled RMSE=2.355436
# ================
# feature num 2, score = 2.355436
# Property #2:    raw RMSE=1.657072
# Property #2: scaled RMSE=1.657072
# ================
# feature num 2, score = 1.657072
# Property #2:    raw RMSE=1.668594
# Property #2: scaled RMSE=1.668594
# ================
# feature num 2, score = 1.668594
# Property #2:    raw RMSE=1.218463
# Property #2: scaled RMSE=1.218463
# ================
# feature num 2, score = 1.218463
# Property #2:    raw RMSE=1.997154
# Property #2: scaled RMSE=1.997154
# ================
# feature num 2, score = 1.997154
# Property #2:    raw RMSE=1.191538
# Property #2: scaled RMSE=1.191538
# ================
# feature num 2, score = 1.191538
# Property #2:    raw RMSE=2.133094
# Property #2: scaled RMSE=2.133094
# ================
# feature num 2, score = 2.133094
# Property #2:    raw RMSE=1.399279
# Property #2: scaled RMSE=1.399279
# ================
# feature num 2, score = 1.399279
# Property #2:    raw RMSE=1.442938
# Property #2: scaled RMSE=1.442938
# ================
# feature num 2, score = 1.442938
# Property #2:    raw RMSE=1.676769
# Property #2: scaled RMSE=1.676769
# ================
# feature num 2, score = 1.676769
# Property #2:    raw RMSE=1.621556
# Property #2: scaled RMSE=1.621556
# ================
# feature num 2, score = 1.621556
# Property #2:    raw RMSE=2.401141
# Property #2: scaled RMSE=2.401141
# ================
# feature num 2, score = 2.401141
# Property #2:    raw RMSE=1.695525
# Property #2: scaled RMSE=1.695525
# ================
# feature num 2, score = 1.695525
# Property #2:    raw RMSE=1.308167
# Property #2: scaled RMSE=1.308167
# ================
# feature num 2, score = 1.308167
# Property #2:    raw RMSE=1.915827
# Property #2: scaled RMSE=1.915827
# ================
# feature num 2, score = 1.915827
# Property #2:    raw RMSE=1.311604
# Property #2: scaled RMSE=1.311604
# ================
# feature num 2, score = 1.311604
# Property #2:    raw RMSE=1.347754
# Property #2: scaled RMSE=1.347754
# ================
# feature num 2, score = 1.347754
# Property #2:    raw RMSE=2.070462
# Property #2: scaled RMSE=2.070462
# ================
# feature num 2, score = 2.070462
# Property #2:    raw RMSE=1.716564
# Property #2: scaled RMSE=1.716564
# ================
# feature num 2, score = 1.716564
# Property #2:    raw RMSE=1.617061
# Property #2: scaled RMSE=1.617061
# ================
# feature num 2, score = 1.617061
# Property #2:    raw RMSE=2.219451
# Property #2: scaled RMSE=2.219451
# ================
# feature num 2, score = 2.219451
# Property #2:    raw RMSE=1.760873
# Property #2: scaled RMSE=1.760873
# ================
# feature num 2, score = 1.760873
# Property #2:    raw RMSE=1.849817
# Property #2: scaled RMSE=1.849817
# ================
# feature num 2, score = 1.849817
# Property #2:    raw RMSE=2.092674
# Property #2: scaled RMSE=2.092674
# ================
# feature num 2, score = 2.092674
# Property #2:    raw RMSE=1.522291
# Property #2: scaled RMSE=1.522291
# ================
# feature num 2, score = 1.522291
# Property #2:    raw RMSE=1.388150
# Property #2: scaled RMSE=1.388150
# ================
# feature num 2, score = 1.388150
# Property #2:    raw RMSE=2.226221
# Property #2: scaled RMSE=2.226221
# ================
# feature num 2, score = 2.226221
# Property #2:    raw RMSE=1.598869
# Property #2: scaled RMSE=1.598869
# ================
# feature num 2, score = 1.598869
# Property #2:    raw RMSE=1.674476
# Property #2: scaled RMSE=1.674476
# ================
# feature num 2, score = 1.674476
# Property #2:    raw RMSE=1.296481
# Property #2: scaled RMSE=1.296481
# ================
# feature num 2, score = 1.296481
# Property #2:    raw RMSE=1.470774
# Property #2: scaled RMSE=1.470774
# ================
# feature num 2, score = 1.470774
# Property #2:    raw RMSE=2.164676
# Property #2: scaled RMSE=2.164676
# ================
# feature num 2, score = 2.164676
# Property #2:    raw RMSE=1.853828
# Property #2: scaled RMSE=1.853828
# ================
# feature num 2, score = 1.853828
# Property #2:    raw RMSE=1.761782
# Property #2: scaled RMSE=1.761782
# ================
# feature num 2, score = 1.761782
# Property #2:    raw RMSE=1.622727
# Property #2: scaled RMSE=1.622727
# ================
# feature num 2, score = 1.622727
# Property #2:    raw RMSE=1.564701
# Property #2: scaled RMSE=1.564701
# ================
# feature num 2, score = 1.564701
# Property #2:    raw RMSE=1.677539
# Property #2: scaled RMSE=1.677539
# ================
# feature num 2, score = 1.677539
# Property #2:    raw RMSE=1.420929
# Property #2: scaled RMSE=1.420929
# ================
# feature num 2, score = 1.420929
# Property #2:    raw RMSE=2.060721
# Property #2: scaled RMSE=2.060721
# ================
# feature num 2, score = 2.060721
# Property #2:    raw RMSE=2.277117
# Property #2: scaled RMSE=2.277117
# ================
# feature num 2, score = 2.277117
# Property #2:    raw RMSE=1.982389
# Property #2: scaled RMSE=1.982389
# ================
# feature num 2, score = 1.982389
# Property #2:    raw RMSE=2.175171
# Property #2: scaled RMSE=2.175171
# ================
# feature num 2, score = 2.175171
# Property #2:    raw RMSE=1.793790
# Property #2: scaled RMSE=1.793790
# ================
# feature num 2, score = 1.793790
# Property #2:    raw RMSE=2.069613
# Property #2: scaled RMSE=2.069613
# ================
# feature num 2, score = 2.069613
# Property #2:    raw RMSE=1.439603
# Property #2: scaled RMSE=1.439603
# ================
# feature num 2, score = 1.439603
# Property #2:    raw RMSE=1.485502
# Property #2: scaled RMSE=1.485502
# ================
# feature num 2, score = 1.485502
# Property #2:    raw RMSE=2.331013
# Property #2: scaled RMSE=2.331013
# ================
# feature num 2, score = 2.331013
# Property #2:    raw RMSE=1.629431
# Property #2: scaled RMSE=1.629431
# ================
# feature num 2, score = 1.629431
# Property #2:    raw RMSE=1.794007
# Property #2: scaled RMSE=1.794007
# ================
# feature num 2, score = 1.794007
# Property #2:    raw RMSE=1.975235
# Property #2: scaled RMSE=1.975235
# ================
# feature num 2, score = 1.975235
# Property #2:    raw RMSE=1.923069
# Property #2: scaled RMSE=1.923069
# ================
# feature num 2, score = 1.923069
# Property #2:    raw RMSE=1.657028
# Property #2: scaled RMSE=1.657028
# ================
# feature num 2, score = 1.657028
# Property #2:    raw RMSE=1.746385
# Property #2: scaled RMSE=1.746385
# ================
# feature num 2, score = 1.746385
# Property #2:    raw RMSE=1.502826
# Property #2: scaled RMSE=1.502826
# ================
# feature num 2, score = 1.502826
# Property #2:    raw RMSE=1.136486
# Property #2: scaled RMSE=1.136486
# ================
# feature num 2, score = 1.136486
# Property #2:    raw RMSE=1.515697
# Property #2: scaled RMSE=1.515697
# ================
# feature num 2, score = 1.515697
# Property #2:    raw RMSE=1.925607
# Property #2: scaled RMSE=1.925607
# ================
# feature num 2, score = 1.925607
# Property #2:    raw RMSE=2.124239
# Property #2: scaled RMSE=2.124239
# ================
# feature num 2, score = 2.124239
# Property #2:    raw RMSE=1.868826
# Property #2: scaled RMSE=1.868826
# ================
# feature num 2, score = 1.868826
# Property #2:    raw RMSE=2.154932
# Property #2: scaled RMSE=2.154932
# ================
# feature num 2, score = 2.154932
# Property #2:    raw RMSE=1.391930
# Property #2: scaled RMSE=1.391930
# ================
# feature num 2, score = 1.391930
# Property #2:    raw RMSE=2.251987
# Property #2: scaled RMSE=2.251987
# ================
# feature num 2, score = 2.251987
# Property #2:    raw RMSE=1.529781
# Property #2: scaled RMSE=1.529781
# ================
# feature num 2, score = 1.529781
# Property #2:    raw RMSE=1.798742
# Property #2: scaled RMSE=1.798742
# ================
# feature num 2, score = 1.798742
# Property #2:    raw RMSE=1.921512
# Property #2: scaled RMSE=1.921512
# ================
# feature num 2, score = 1.921512

# %%
X_train_c_0 = X_train_c[:, features_results[0][min(features_results[0])]]
X_train_c_1 = X_train_c[:, features_results[1][min(features_results[1])]]
X_train_c_2 = X_train_c[:, features_results[2][min(features_results[2])]]

X_val_c_0 = X_val_c[:, features_results[0][min(features_results[0])]]
X_val_c_1 = X_val_c[:, features_results[1][min(features_results[1])]]
X_val_c_2 = X_val_c[:, features_results[2][min(features_results[2])]]

# %%
total_score = 0
for feature_number in range(3):
  total_score += test_solution(
      [X_train_c_0, X_train_c_1, X_train_c_2][feature_number],
      y_train,
      [X_val_c_0, X_val_c_1, X_val_c_2][feature_number],
      y_val,
      feature_num=feature_number
  )
  print()
total_score /= 3
print('='*16)
print(f"Total score = {total_score:.6f}")
# Out:
# Property #0:    raw RMSE=0.205094
# Property #0: scaled RMSE=1.367290
#
# Property #1:    raw RMSE=0.099386
# Property #1: scaled RMSE=1.242330
#
# Property #2:    raw RMSE=1.103868
# Property #2: scaled RMSE=1.103868
#
# ================
# Total score = 1.237829

# %% [markdown]
# # Author solution
#
# - Replicate the data 5 more times, swapping axes (number of permutations for three axes)
#
# - (Optionally) Delete duplicate columns
#
# - Use PCA, it helps
#
# - (Author's knowledge) One of the features is from the previous task, gives biggest improvement, so home-task knowledge definitely helps
#
# Most successful teams combined some replication(=augmentation), features from home task, and PCA. Validation set should be a good indicator whether particular feature is a good idea to add.

# %%
def symmetrize_x(X_tr, y_tr):
    xxx = [
        X_tr,
        X_tr.swapaxes(1, 2),
        X_tr.swapaxes(1, 3),
        X_tr.swapaxes(2, 3),
        X_tr.swapaxes(1, 3).swapaxes(1, 2),
        X_tr.swapaxes(1, 3).swapaxes(2, 3),
    ]
    return np.concatenate(xxx), np.vstack([y_tr]*6)

# %%
def ravelize(X):
    return X.reshape((X.shape[0], -1))

# %%
def make_bg(X):
    bgs = []
    for _x in X:
        bg = _x[:,:,:,3].ravel().min() - _x[:,:,:,2].ravel().max()
        bgs.append(bg)
    bgs = np.array(bgs)
    return bgs[:, None]

# %%
X_train_symm, y_train_symm = symmetrize_x(X_train, y_train)

# %%
# X_train_bg = make_bg(X_train_symm)
# X_val_bg = make_bg(X_val)
X_train_c = construct_features(X_train_symm)
X_val_c = construct_features(X_val)
best_idxs = features_results[min(features_results)]
X_train_c = X_train_c[:, best_idxs]
X_val_c = X_val_c[:, best_idxs]
# Out:
# <ipython-input-137-8ff1a3e9b313>:27: RuntimeWarning: divide by zero encountered in divide
#   (features[:, comb[0]] / features[:, comb[1]]).reshape(-1,1)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=100)
X_train_pca = pca.fit_transform(ravelize(X_train_symm))
X_val_pca = pca.transform(ravelize(X_val))
# X_train_pca = pca.fit_transform(X_train_c)
# X_val_pca = pca.transform(X_val_c)

# %%
# %%time
total_score = 0
for feature_number in range(3):
  total_score += test_solution(
      X_train_pca,
      y_train_symm,
      X_val_pca,
      y_val,
      feature_num=feature_number
  )
  print()
total_score /= 3
print('='*16)
print(f"Total score = {total_score:.6f}")
# Out:
# Property #0:    raw RMSE=0.305542
# Property #0: scaled RMSE=2.036950
#
# Property #1:    raw RMSE=0.596131
# Property #1: scaled RMSE=7.451637
#
# Property #2:    raw RMSE=1.631475
# Property #2: scaled RMSE=1.631475
#
# ================
# Total score = 3.666667
# CPU times: user 3.01 s, sys: 20.7 ms, total: 3.03 s
# Wall time: 2.59 s

# %%
# %%time
total_score = 0
# something close to the best possible solution
for feature_number in range(3):
  total_score += test_solution(
      np.concatenate([X_train_pca, X_train_c], axis=-1),
      # X_train_bg,
      y_train_symm,
      # X_val_bg,
      np.concatenate([X_val_pca, X_val_c], axis=-1),
      y_val,
      feature_num=feature_number
  )
  print()
total_score /= 3
print('='*16)
print(f"Total score = {total_score:.6f}")
# Out:
# Property #0:    raw RMSE=0.145149
# Property #0: scaled RMSE=0.967662
#
# Property #1:    raw RMSE=0.101555
# Property #1: scaled RMSE=1.269434
#
# Property #2:    raw RMSE=3.093128
# Property #2: scaled RMSE=3.093128
#
# ================
# Total score = 1.666667
# CPU times: user 3.68 s, sys: 91.1 ms, total: 3.77 s
# Wall time: 3.05 s

# %%
np.concatenate([X_train_pca, X_train_c], axis=-1).shape
# Out:
# (12144, 1870)
